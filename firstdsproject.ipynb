# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df = pd.read_csv('superheroes_v3.csv')

# %%
df
# Out:
#       Unnamed: 0 Alignment Alter_Egos            Base  \
# 0              0      Good       None            None
# 1              1      Good       None            None
# 2              2      Good       None            None
# 3              3   Neutral       None            None
# 4              4      Good       None            None
# ...          ...       ...        ...             ...
# 8306        4374       Bad    Zeldris            None
# 8307        4375      Good       None            None
# 8308        4376      Good       Yuno  Clover Kingdom
# 8309        4377      None       None            None
# 8310        4378      None       None            None
#
#                     Character   Class_value  \
# 0                     Alucard  5.471000e+03
# 1                     Alucard  2.586011e+06
# 2                     Alucard  1.170000e+03
# 3                   Bayonetta  1.006270e+05
# 4                        Adam  4.000000e+01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8311 entries, 0 to 8310
# Data columns (total 39 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      8311 non-null   int64
#  1   Alignment       8311 non-null   object
#  2   Alter_Egos      8311 non-null   object
#  3   Base            8309 non-null   object
#  4   Character       8311 non-null   object
#  5   Class_value     8311 non-null   float64
#  6   Collections     8311 non-null   object
#  7   Combat          8311 non-null   int64
#  8   Creator         8311 non-null   object
#  9   Durability      8311 non-null   int64
#  10  Equipment       578 non-null    object
#  11  Eye_color       8311 non-null   object
#  12  Formerly        8311 non-null   object
#  13  Full_name       8311 non-null   object
#  14  Gender          8311 non-null   object
#  15  Hair_color      8311 non-null   object
#  16  Height          8311 non-null   object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Alignment Alter_Egos  Base  Character  Class_value  \
# 0           0      Good       None  None    Alucard       5471.0
# 1           1      Good       None  None    Alucard    2586011.0
# 2           2      Good       None  None    Alucard       1170.0
# 3           3   Neutral       None  None  Bayonetta     100627.0
# 4           4      Good       None  None       Adam         40.0
#
#                                          Collections  Combat Creator  \
# 0                                               None      80  Konami
# 1                                               None      90  Konami
# 2                                               None     100    None
# 3  Anti-heroes,Gamekings,Roleplaying Collection,V...      90    Sega
# 4                                               None      40    None
#
#    Durability  ...                                          Relatives  \
# 0          35  ...           Vlad Ţepeş (father)\nLisa Ţepeş (mother)
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0   Class_value       Combat   Durability           IQ  \
# count  8311.000000  8.311000e+03  8311.000000  8311.000000  8311.000000
# mean   2034.910600  3.654365e+10    68.389604    51.522921   143.364457
# std    1213.747037  5.437194e+11    27.097392    35.814086    36.651442
# min       0.000000  1.000000e+00     1.000000     1.000000     0.000000
# 25%     986.000000  1.390000e+02    50.000000    16.000000   120.000000
# 50%    2025.000000  2.151000e+03    70.000000    40.000000   140.000000
# 75%    3063.500000  2.574425e+05    95.000000   100.000000   170.000000
# max    4378.000000  4.677292e+13   100.000000   100.000000   200.000000
#
#        Intelligence        Level  Omnipotent  Omnipresent   Omniscient  \
# count   8311.000000  8311.000000      8311.0  8311.000000  8311.000000
# mean      71.857659     3.182048         0.0     0.050896     0.017808
# std       18.278224     1.805446         0.0     0.219799     0.132260
# ...

# %%
df['Alignment'].value_counts() #
# Out:
# Good       3271
# Bad        2030
# None       1774
# Neutral     952
# -           284
# Name: Alignment, dtype: int64

# %%
df['Creator'].value_counts()
# Out:
# Marvel Comics            1590
# DC Comics                1439
# None                     1230
# Shueisha                  902
# Cartoon Network           199
#                          ...
# SyFy                        1
# Herg�                       1
# Gene Roddenberry            1
# Kevin Williamson            1
# Absolute Comics Group       1
# Name: Creator, Length: 91, dtype: int64

# %%
df['Speed'].max(), df['Speed'].min(), df['Speed'].mean()
# Out:
# (100, 1, 50.28299843580797)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=0)

# %%
y = df['Power']

# Create feature variables
X = df.drop('Power', axis=1)

# %%
for train_index, test_index in split.split(X, y):
    # Get the training data
    X_train, X_test = X.iloc[train_index], y.iloc[test_index]
    y_train, y_test = X.iloc[train_index], y.iloc[test_index]

# %%
from pandas_profiling import ProfileReport

# %%
pp_report = ProfileReport(y_train)
